# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from datetime import datetime

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create an engine
engine = create_engine("sqlite:///db/wine.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes/tables that automap found
Base.classes.keys()
# Out:
# ['map_wine_table', 'wine_table']

# %%
# Save references to the table
Wine = Base.classes.wine_table

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# inspecting the columns
columns = inspector.get_columns('wine_table')   
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# country VARCHAR(255)
# description VARCHAR(1000)
# points FLOAT
# price FLOAT
# province VARCHAR(255)
# region_1 VARCHAR(255)
# region_2 VARCHAR(255)
# variety VARCHAR(255)
# winery VARCHAR(255)

# %%
# inspecting the rows Measurement Table 
# engine.execute('select * from wine_table LIMIT 5').fetchall()

# %%
# Design a query to show how many wineries are available in this dataset?
session.query(func.count(Wine.winery)).all()
# Out:
# [(137230)]

# %% [markdown]
# # Wineries that got the most reviews

# %%
# What are the most active winaries? Listing the stations and the 
# counts in descending order.
# We have to join two tables on "station"
session.query(Wine.winery, Wine.country, func.count(Wine.winery)).\
    group_by(Wine.winery).\
    order_by(func.count(Wine.winery).desc()).all()
# Out:
# [('Williams Selyem', 371),
#  ('Testarossa', 274),
#  ('DFJ Vinhos', 249),
#  ('Chateau Ste. Michelle', 225),
#  ('Columbia Crest', 216),
#  ('Kendall-Jackson', 216),
#  ('Concha y Toro', 214),
#  ('Trapiche', 201),
#  ('Bouchard Père & Fils', 192),
#  ('De Loach', 189),
#  ('Joseph Drouhin', 185),
#  ('Kenwood', 183),
#  ('Cameron Hughes', 172),
#  ("D'Arenberg", 153),
#  ('Dry Creek Vineyard', 153),
#  ('Louis Latour', 153),
#  ('Morgan', 153),
#  ('Concannon', 151),
#  ('Robert Mondavi', 151),
#  ('Martin Ray', 149),
#  ('Errazuriz', 148),
#  ('Wines & Winemakers', 148),
#  ("L'Ecole No. 41", 144),
#  ('Iron Horse', 142),
#  ('Montes', 142),
#  ('Renwood', 141),
#  ('Santa Rita', 141),
#  ('Waterbrook', 141),
#  ('Calera', 140),
#  ('Hogue', 139),
#  ('Yalumba', 139),
#  ('Gary Farrell', 138),
#  ('Santa Ema', 137),
#  ('Sineann', 137),
#  ('Bodega Norton', 134),
#  ('Seven Hills', 130),
#  ('Rodney Strong', 128),
#  ('Wellington', 127),
#  ('Novy', 124),
#  ('Viu Manent', 123),
#  ('Adelaida', 122),
#  ('Planeta', 121),
#  ('Saint Clair', 121),
#  ('Thomas Fogarty', 121),
#  ('Dutton-Goldfield', 120),
#  ('Penfolds', 119),
#  ('Brander', 118),
#  ('Fess Parker', 116),
#  ('Beringer', 115),
#  ('J. Lohr', 115),
#  ('Peachy Canyon', 115),
#  ('Siduri', 114),
#  ('Tamarack Cellars', 113),
#  ('Bernardus', 112),
#  ('Clos La Chance', 112),
#  ('Dr. Loosen', 111),
#  ('EOS', 111),
#  ('Lapostolle', 111),
#  ('Louis Jadot', 110),
#  ('Luigi Bosca', 110),
#  ('Raymond', 110),
#  ('Tommasi', 110),
#  ('Kunde', 109),
#  ('Lynmar', 108),
#  ('Adelsheim', 107),
#  ('Castle Rock', 107),
#  ('Erath', 107),
#  ('Olivier Leflaive', 107),
#  ('Santa Carolina', 107),
#  ('Talley', 107),
#  ('Undurraga', 107),
#  ('De Bortoli', 106),
#  ('Pride Mountain', 106),
#  ('O. Fournier', 105),
#  ('Robert Hall', 105),
#  ('Airfield Estates', 104),
#  ('Three Rivers', 104),
#  ('K Vintners', 103),
#  ('Dusted Valley', 102),
#  ('Merry Edwards', 102),
#  ('Sebastiani', 102),
#  ('Willamette Valley Vineyards', 102),
#  ('Ferrari-Carano', 101),
#  ('Ken Wright', 101),
#  ('Maryhill', 101),
#  ('San Pedro', 101),
#  ('Schug', 101),
#  ('Chateau St. Jean', 100),
#  ('Longoria', 99),
#  ('Bonterra', 98),
#  ('Buena Vista', 98),
#  ('Joseph Swan Vineyards', 98),
#  ('Santa Alicia', 98),
#  ('Santa Julia', 98),
#  ('Bodega Catena Zapata', 97),
#  ('Failla', 97),
#  ('Fenestra', 97),
#  ('Flora Springs', 97),
#  ('Geyser Peak', 97),
#  ('Morandé', 97),
#  ('Rocca delle Macìe', 97),
#  ('Beaulieu Vineyard', 96),
#  ('Feudi di San Gregorio', 96),
#  ('Recanati', 96),
#  ('Merryvale', 95),
#  ('Michel Torino', 95),
#  ('Ojai', 95),
#  ('Pedroncelli', 95),
#  ('Simonnet-Febvre', 95),
#  ('Foxen', 94),
#  ('Miguel Torres', 94),
#  ('Pascual Toso', 94),
#  ('Vina Robles', 94),
#  ('Companhia das Quintas', 93),
#  ('Domaines Barons de Rothschild (Lafite)', 93),
#  ('Echeverria', 93),
#  ('Tolosa', 93),
#  ('Valentin Bianchi', 93),
#  ('Familia Schroeder', 92),
#  ('Gérard Bertrand', 92),
#  ('Dão Sul', 91),
#  ('Odfjell', 91),
#  ("Tasca d'Almerita", 91),
#  ('V. Sattui', 90),
#  ('Covey Run', 89),
#  ('Golan Heights Winery', 89),
#  ('Midnight', 89),
#  ('Rosenblum', 89),
#  ('Sobon Estate', 89),
#  ('Terre Rouge', 88),
#  ('Artesa', 87),
#  ('Cline', 87),
#  ('Easton', 87),
#  ('Freixenet', 87),
#  ('Poças', 87),
#  ('Sterling', 87),
#  ('Clos Pegase', 86),
#  ('Eberle', 86),
#  ('François Lurton', 86),
#  ('Lungarotti', 86),
#  ('Barton & Guestier', 85),
#  ('Chanson Père et Fils', 85),
#  ('Finca Sophenia', 85),
#  ('Milbrandt', 85),
#  ('Villa Maria', 85),
#  ('Fetzer', 84),
#  ('Ironstone', 84),
#  ('Bogle', 83),
#  ('Dr. Pauly Bergweiler', 83),
#  ('Lucien Albrecht', 83),
#  ('St. Francis', 83),
#  ('Valley of the Moon', 83),
#  ('Abacela', 82),
#  ('Babcock', 82),
#  ('Bründlmayer', 82),
#  ('Carmen', 82),
#  ('Domaine Faiveley', 82),
#  ('Hahn', 82),
#  ("Jacob's Creek", 82),
#  ('Marqués de Cáceres', 82),
#  ('Signorello', 82),
#  ('Trivento', 82),
#  ('Barnard Griffin', 81),
#  ('Columbia Winery', 81),
#  ('Marimar Estate', 81),
#  ('San Simeon', 81),
#  ('Gloria Ferrer', 80),
#  ('J Vineyards & Winery', 80),
#  ('Kilikanoon', 80),
#  ('MacPhail', 80),
#  ('Minassian-Young', 80),
#  ('TerraNoble', 80),
#  ('Chehalem', 79),
#  ('Clos du Bois', 79),
#  ('Clos du Val', 79),
#  ('La Fenêtre', 79),
#  ('David Hill', 78),
#  ('Domaine Zind-Humbrecht', 78),
#  ('Quinta de Ventozelo', 78),
#  ('Torres', 78),
#  ('Francis Ford Coppola', 77),
#  ("Frog's Leap", 77),
#  ('J. & F. Lurton', 77),
#  ('McManis', 77),
#  ('Pali', 77),
#  ('Patz & Hall', 77),
#  ('Emiliana', 76),
#  ('Kirkland Signature', 76),
#  ('Pierre Sparr', 76),
#  ('Rex Hill', 76),
#  ("Stag's Leap Wine Cellars", 76),
#  ('Syncline', 76),
#  ('Andeluna', 75),
#  ('Bodegas Valdemar', 75),
#  ('Carmel', 75),
#  ('E. Guigal', 75),
#  ('Gainey', 75),
#  ('Lucas & Lewellen', 75),
#  ('Ramos-Pinto', 75),
#  ('Salomon-Undhof', 75),
#  ('Segura Viudas', 75),
#  ('Winzer Krems', 75),
#  ('Arista', 74),
#  ('Chilcas', 74),
#  ('Cono Sur', 74),
#  ('Cusumano', 74),
#  ('Labouré-Roi', 74),
#  ('Ponzi', 74),
#  ('Sierra Cantabria', 74),
#  ('Snoqualmie', 74),
#  ('Viña Bisquertt', 74),
#  ('Zaca Mesa', 74),
#  ('Bacalhôa Wines of Portugal', 73),
#  ('Castello Banfi', 73),
#  ('Charles Krug', 73),
#  ('Doña Paula', 73),
#  ('Feudo Arancio', 73),
#  ('Roessler', 73),
#  ("Valle dell'Acate", 73),
#  ('Brancott', 72),
#  ('Byron', 72),
#  ('Castoro Cellars', 72),
#  ('Ceretto', 72),
#  ('Gunter Triebaumer', 72),
#  ('Hendry', 72),
#  ('M. Chapoutier', 72),
#  ('Maximin Grünhäuser', 72),
#  ('Peju', 72),
#  ('Schramsberg', 72),
#  ('William Fèvre', 72),
#  ('Caliterra', 71),
#  ('Etude', 71),
#  ('Laetitia', 71),
#  ('Nefarious Cellars', 71),
#  ('Rutini', 71),
#  ('Wagner', 71),
#  ('Boutari', 70),
#  ('Brian Carter Cellars', 70),
#  ('Estancia', 70),
#  ('Felton Road', 70),
#  ('Peirano', 70),
#  ('Rusack', 70),
#  ('Sbragia', 70),
#  ('St. Supéry', 70),
#  ('Summers', 70),
#  ('Andrew Will', 69),
#  ('Caves Aliança', 69),
#  ('Funky Llama', 69),
#  ('Henri de Villamont', 69),
#  ('Niepoort', 69),
#  ('Arbor Crest', 68),
#  ('Barrister', 68),
#  ('Cambria', 68),
#  ('Craggy Range', 68),
#  ('Duckhorn', 68),
#  ('Joseph Phelps', 68),
#  ('La Playa', 68),
#  ('Longboard', 68),
#  ('Mazzocco', 68),
#  ('Shannon Ridge', 68),
#  ('Stevens', 68),
#  ('Buty', 67),
#  ('Dutton Estate', 67),
#  ('Rancho Sisquoc', 67),
#  ('Wilson', 67),
#  ('Zuccardi', 67),
#  ('Aresti', 66),
#  ('Ballentine', 66),
#  ('Calcareous', 66),
#  ('Carpineto', 66),
#  ('Kynsi', 66),
#  ('Alexander Valley Vineyards', 65),
#  ('Arboleda', 65),
#  ('Bouchard Aîné & Fils', 65),
#  ('Carlos Basso', 65),
#  ('Del Rio', 65),
#  ('Dr. Konstantin Frank', 65),
#  ('Heron Hill', 65),
#  ('Kokomo', 65),
#  ('Martin & Weyrich', 65),
#  ('Nieto Senetiner', 65),
#  ('Novelty Hill', 65),
#  ('Quinta do Portal', 65),
#  ('Santa Barbara Winery', 65),
#  ('Casa Silva', 64),
#  ('Curtis', 64),
#  ('DeLille', 64),
#  ('Husch', 64),
#  ('Kumeu River', 64),
#  ('Lockwood', 64),
#  ('Luis Felipe Edwards', 64),
#  ('Ventisquero', 64),
#  ('Arrowood', 63),
#  ('Balletto', 63),
#  ('Chalk Hill', 63),
#  ('Georges Vigouroux', 63),
#  ('Girard', 63),
#  ('Handley', 63),
#  ('La Chablisienne', 63),
#  ('La Rochelle', 63),
#  ('Maddalena', 63),
#  ('Viña Requingua', 63),
#  ('Wente', 63),
#  ('Abeja', 62),
#  ('Campolargo', 62),
#  ('Domaines Schlumberger', 62),
#  ('Dunham', 62),
#  ('Keenan', 62),
#  ('Murphy-Goode', 62),
#  ('Navarro', 62),
#  ('Nittnaus Hans und Christine', 62),
#  ('Thurston Wolfe', 62),
#  ('Domaine Jean Bousquet', 61),
#  ('Freemark Abbey', 61),
#  ('Herdade do Esporão', 61),
#  ('King Estate', 61),
#  ('Korbel', 61),
#  ('Leonetti Cellar', 61),
#  ('Louis M. Martini', 61),
#  ('Producteurs Plaimont', 61),
#  ('Saviah', 61),
#  ('Tamaya', 61),
#  ('Tandem', 61),
#  ('Woodward Canyon', 61),
#  ('Alexandria Nicole', 60),
#  ('Bianchi', 60),
#  ('Borges', 60),
#  ('Domaine des Baumard', 60),
#  ('Jaffurs', 60),
#  ('La Crema', 60),
#  ('Marchesi di Barolo', 60),
#  ('Mazzei', 60),
#  ('Neil Ellis', 60),
#  ('Paraiso Vineyards', 60),
#  ('Pio Cesare', 60),
#  ('Spy Valley', 60),
#  ('William Hill Estate', 60),
#  ('Basel Cellars', 59),
#  ('CVNE', 59),
#  ('Domdechant Werner', 59),
#  ('Panther Creek', 59),
#  ('Shafer', 59),
#  ('Soléna', 59),
#  ('Steele', 59),
#  ('Benziger', 58),
#  ('Cuvaison', 58),
#  ('Epiphany', 58),
#  ('Gamache', 58),
#  ('Januik', 58),
#  ('Kim Crawford', 58),
#  ('Nickel & Nickel', 58),
#  ('Pratsch', 58),
#  ('Rosemount', 58),
#  ('Trinchero', 58),
#  ('Von Strasser', 58),
#  ('Astoria', 57),
#  ('Bodegas Navarro López', 57),
#  ('Cantina Santadi', 57),
#  ('Clarendon Hills', 57),
#  ('De Martino', 57),
#  ('Domaine de la Terre Rouge', 57),
#  ('Guenoc', 57),
#  ('Reichsgraf von Kesselstatt', 57),
#  ('Spring Valley Vineyard', 57),
#  ('Sylvester', 57),
#  ('Telmo Rodríguez', 57),
#  ('Veramonte', 57),
#  ('Viña Tabalí', 57),
#  ('Wakefield Estate', 57),
#  ('Wölffer', 57),
#  ('Cadence', 56),
#  ('Domaine Serene', 56),
#  ('Doyenne', 56),
#  ('Hanna', 56),
#  ('Loring Wine Company', 56),
#  ('Mumm Napa', 56),
#  ('Paul Jaboulet Aîné', 56),
#  ('Pessagno', 56),
#  ('Pine Ridge', 56),
#  ('Sequoia Grove', 56),
#  ('Tablas Creek', 56),
#  ('Talbott', 56),
#  ('Terlato', 56),
#  ('Betz Family', 55),
#  ('Carr', 55),
#  ('Cinnabar', 55),
#  ('El Coto', 55),
#  ('Firestone', 55),
#  ('Fritz', 55),
#  ('Manuel Olivier', 55),
#  ('Marchesi Antinori', 55),
#  ('MontGras', 55),
#  ('Quinta do Casal Branco', 55),
#  ('Standing Stone', 55),
#  ('Steven Kent', 55),
#  ('Talamonti', 55),
#  ('Tangent', 55),
#  ('Tertulia', 55),
#  ('Umani Ronchi', 55),
#  ('Zull', 55),
#  ('Barnett', 54),
#  ('Cayuse', 54),
#  ('Donnafugata', 54),
#  ('Estampa', 54),
#  ('Glenora', 54),
#  ('Leeuwin Estate', 54),
#  ('Lost Canyon', 54),
#  ('Mounts', 54),
#  ('Rock Wall', 54),
#  ('Sur de los Andes', 54),
#  ('Torii Mor', 54),
#  ('White Oak', 54),
#  ('Blackstone', 53),
#  ('Chandon', 53),
#  ('Fidelitas', 53),
#  ('Goldeneye', 53),
#  ('Gorman', 53),
#  ('Lamoreaux Landing', 53),
#  ('Lava Cap', 53),
#  ('Lemelson', 53),
#  ('Louis Roederer', 53),
#  ('Melrose', 53),
#  ('Quivira', 53),
#  ('Sparkman', 53),
#  ('X', 53),
#  ('Alta Vista', 52),
#  ('Cave B', 52),
#  ('Chimney Rock', 52),
#  ('Dr. H. Thanisch (Erben Müller-Burggraef)', 52),
#  ('Duca di Salaparuta', 52),
#  ('Grgich Hills', 52),
#  ('Justin', 52),
#  ('Macari', 52),
#  ('Martin Ranch', 52),
#  ('Owen Roe', 52),
#  ('Ramón Bilbao', 52),
#  ('Rutherford Hill', 52),
#  ('San Juan Vineyards', 52),
#  ('Stephen Ross', 52),
#  ('Adega Cooperativa de Borba', 51),
#  ('Apaltagua', 51),
#  ('Bernard Magrez', 51),
#  ('Dopff & Irion', 51),
#  ('Fournier Père et Fils', 51),
#  ('Hazlitt 1852 Vineyards', 51),
#  ('Lagarde', 51),
#  ('Mark Ryan', 51),
#  ('Melville', 51),
#  ('Remy-Pannier', 51),
#  ('Terrazas de Los Andes', 51),
#  ('Truchard', 51),
#  ('Vine Cliff', 51),
#  ('Vinum', 51),
#  ('Viña La Rosa', 51),
#  ('A to Z', 50),
#  ('Aveleda', 50),
#  ('Black Box', 50),
#  ('Cortes de Cima', 50),
#  ('Dashe Cellars', 50),
#  ('J. Bookwalter', 50),
#  ('Johanneshof Reinisch', 50),
#  ('Le Macchiole', 50),
#  ('Ledson', 50),
#  ('MAN Vintners', 50),
#  ('Matua Valley', 50),
#  ('Michele Chiarlo', 50),
#  ('Mionetto', 50),
#  ('Montevina', 50),
#  ('Mosby', 50),
#  ('Muga', 50),
#  ('Oveja Negra', 50),
#  ('Poderi Luigi Einaudi', 50),
#  ('Salentein', 50),
#  ('Sanford', 50),
#  ('Siegel', 50),
#  ('Villa Sandi', 50),
#  ('Vin du Lac', 50),
#  ('Wild Horse', 50),
#  (':Nota Bene', 49),
#  ('Angeline', 49),
#  ('Faiveley', 49),
#  ('Fox Run', 49),
#  ('Frank Family', 49),
#  ('J. Portugal Ramos', 49),
#  ('JM Cellars', 49),
#  ('José Maria da Fonseca', 49),
#  ('Muscardini', 49),
#  ('Simi', 49),
#  ('Airlie', 48),
#  ('Amador Foothill Winery', 48),
#  ('Anam Cara', 48),
#  ('Chilensis', 48),
#  ('Claudia Springs', 48),
#  ('Domaine Alfred', 48),
#  ('Kaiken', 48),
#  ('Loimer', 48),
#  ('Mastroberardino', 48),
#  ('Methven Family Vineyards', 48),
#  ('Mirassou', 48),
#  ('Monticello Vineyards', 48),
#  ('Piccini', 48),
#  ('Vicente Gandia', 48),
#  ('Zolo', 48),
#  ('Antonin Rodet', 47),
#  ('Borsao', 47),
#  ('Domaine Carneros', 47),
#  ('Domaine Leflaive', 47),
#  ('Graffigna', 47),
#  ('Graham Beck', 47),
#  ('Grant Burge', 47),
#  ('Masi', 47),
#  ('Matanzas Creek', 47),
#  ('Penley Estate', 47),
#  ('Pietra Santa', 47),
#  ('Ridge', 47),
#  ('Robert Stemmler', 47),
#  ('Sojourn', 47),
#  ('Walla Walla Vintners', 47),
#  ('Ampelos', 46),
#  ('Ancient Peaks', 46),
#  ('Big House', 46),
#  ('Cave de Ribeauvillé', 46),
#  ('Chaddsford', 46),
#  ('Conn Creek', 46),
#  ('Domaine Marcel Deiss', 46),
#  ('Georges Duboeuf', 46),
#  ('Lafond', 46),
#  ('Robert Karl', 46),
#  ('Roche', 46),
#  ('Septima', 46),
#  ('Vega Sindoa', 46),
#  ('Backsberg', 45),
#  ('Baileyana', 45),
#  ('Boudreaux Cellars', 45),
#  ('Delas Frères', 45),
#  ('Feudi del Pisciotto', 45),
#  ('Hosmer', 45),
#  ('Jekel', 45),
#  ('Josef Ehmoser', 45),
#  ('Joseph Mellot', 45),
#  ('Keller Estate', 45),
#  ('Pierre Morey', 45),
#  ('Prager', 45),
#  ('S.A. Prüm', 45),
#  ('Soos Creek', 45),
#  ('Thelema', 45),
#  ('Tsantali', 45),
#  ('Two Hands', 45),
#  ('Wolf Blass', 45),
#  ('Argiolas', 44),
#  ('Bodegas Fariña', 44),
#  ('Buttonwood Farm', 44),
#  ('Casale del Giglio', 44),
#  ('Château Bélingard', 44),
#  ('Courtney Benham', 44),
#  ('Damiani', 44),
#  ('Keuka Spring', 44),
#  ('Las Moras', 44),
#  ('Marc Kreydenweiss', 44),
#  ('Rutherford Ranch', 44),
#  ('Sheldrake Point', 44),
#  ('Spring Mountain Vineyard', 44),
#  ('Swanson', 44),
#  ('Ventana', 44),
#  ('Viña Casablanca', 44),
#  ('Woodinville Wine Cellars', 44),
#  ('àMaurice', 44),
#  ('Bargetto', 43),
#  ("Ca' Momi", 43),
#  ('Château Moncontour', 43),
#  ('Coquelicot', 43),
#  ('Cousiño-Macul', 43),
#  ('Cruz Alta', 43),
#  ('Domaine Fouassier', 43),
#  ('Domaine du Tariquet', 43),
#  ('Domaines Ott', 43),
#  ('Efeste', 43),
#  ('Evening Land', 43),
#  ('Goose Ridge', 43),
#  ('Hecht & Bannier', 43),
#  ('Hermann J. Wiemer', 43),
#  ('Jean-Luc Colombo', 43),
#  ('Masciarelli', 43),
#  ('Matetic', 43),
#  ('McCrea', 43),
#  ('Naggiar', 43),
#  ('Oak Grove', 43),
#  ('Pacific Rim', 43),
#  ('Quintay', 43),
#  ('Red Newt Cellars', 43),
#  ('Stolpman', 43),
#  ('Vietti', 43),
#  ('Viña Cobos', 43),
#  ('Banfi', 42),
#  ('Baron De Ley', 42),
#  ('Bertani', 42),
#  ("Ca' Rugate", 42),
#  ("Dow's", 42),
#  ('Emmerich Knoll', 42),
#  ('Grove Mill', 42),
#  ('Herdade de São Miguel', 42),
#  ('Herdade do Rocim', 42),
#  ('Hope Estate', 42),
#  ('Left Coast Cellars', 42),
#  ('MacRostie', 42),
#  ('McCrea Cellars', 42),
#  ('Miner', 42),
#  ('Nautilus', 42),
#  ('Nittnaus Anita und Hans', 42),
#  ('Ravenswood', 42),
#  ('Reverie', 42),
#  ('Sokol Blosser', 42),
#  ('Sunstone', 42),
#  ('Tenute Cisa Asinari dei Marchesi di Gresy', 42),
#  ('Alphonse Mellot', 41),
#  ('Armida', 41),
#  ('Beresan', 41),
#  ('Brutocao', 41),
#  ('Calina', 41),
#  ('Caruso & Minini', 41),
#  ('Casca Wines', 41),
#  ('Château Julien', 41),
#  ("Château d'Esclans", 41),
#  ('Demetria', 41),
#  ('Domaine Costa Lazaridi', 41),
#  ('Foley', 41),
#  ('Graf Hardegg', 41),
#  ('Gundlach Bundschu', 41),
#  ('Hall', 41),
#  ('Herdade da Malhadinha Nova', 41),
#  ('Höpler', 41),
#  ('Jean-Luc Baldès', 41),
#  ('Lakewood', 41),
#  ('M. Cosentino', 41),
#  ('Maison Bleue', 41),
#  ('Markham', 41),
#  ('Mercer', 41),
#  ('Mocali', 41),
#  ('Ortman Family', 41),
#  ('Parducci', 41),
#  ('Principi di Spadafora', 41),
#  ('Rulo', 41),
#  ('Sanguis', 41),
#  ('Sausal', 41),
#  ('Simone', 41),
#  ('Valdivieso', 41),
#  ('Villa Poggio Salvi', 41),
#  ('Walter Dacon', 41),
#  ('Xavier Flouret', 41),
#  ('Beauregard', 40),
#  ('Bridlewood', 40),
#  ('Cantina Terlano', 40),
#  ('Casas del Bosque', 40),
#  ('Cosentino', 40),
#  ('Cristom', 40),
#  ('Di Meo', 40),
#  ('Edna Valley Vineyard', 40),
#  ('Emilio Moro', 40),
#  ('Felsner', 40),
#  ('Feudo Principi di Butera', 40),
#  ('Glen Ellen', 40),
#  ('Hirsch', 40),
#  ('Lyeth', 40),
#  ('Palmer', 40),
#  ('Pellegrini', 40),
#  ('Prado Rey', 40),
#  ('Quinta do Vallado', 40),
#  ('Raptor Ridge', 40),
#  ('Royal Tokaji', 40),
#  ('Silverado', 40),
#  ('Six Sigma Ranch', 40),
#  ('Smoking Loon', 40),
#  ('Tarara', 40),
#  ('Tenuta Rapitalà', 40),
#  ('Wineglass Cellars', 40),
#  ('Woodbridge by Robert Mondavi', 40),
#  ('Yering Station', 40),
#  ('Bailly-Lapierre', 39),
#  ('Barkan', 39),
#  ('Benanti', 39),
#  ('Benessere', 39),
#  ('Camaraderie', 39),
#  ('Chateau Lafayette Reneau', 39),
#  ('Château Cabezac', 39),
#  ('Château du Cèdre', 39),
#  ('Enrique Foster', 39),
#  ('Feiler-Artinger', 39),
#  ('Giacosa Fratelli', 39),
#  ('Hugh Hamilton', 39),
#  ('Jaffelin', 39),
#  ('Kingston Family', 39),
#  ('Lake Sonoma', 39),
#  ('Lolonis', 39),
#  ('Markus Molitor', 39),
#  ('Monte del Frá', 39),
#  ('Palliser Estate', 39),
#  ('Paradise Ridge', 39),
#  ('Pepper Bridge', 39),
#  ('Piattelli', 39),
#  ('Riverbench', 39),
#  ('Robert Weil', 39),
#  ('Ruffino', 39),
#  ('St. Urbans-Hof', 39),
#  ('Te Kairanga', 39),
#  ('Tenuta Sette Ponti', 39),
#  ('The Eyrie Vineyards', 39),
#  ('Ty Caton', 39),
#  ('Vivác Winery', 39),
#  ('Wieninger', 39),
#  ('William Church', 39),
#  ('Zenato', 39),
#  ('Achaia Clauss', 38),
#  ('Alamos', 38),
#  ('Amalie Robert', 38),
#  ('Bodegas Faustino', 38),
#  ('Bodegas Palacio', 38),
#  ('Brandborg', 38),
#  ('Bunnell Family Cellar', 38),
#  ('Castellare di Castellina', 38),
#  ('Castello di Borghese', 38),
#  ('Domaine Vincent Girardin', 38),
#  ('Forgeron', 38),
#  ('Galil Mountain', 38),
#  ('González Byass', 38),
#  ('Henschke', 38),
#  ('Herzog', 38),
#  ('Hunnicutt', 38),
#  ('Johann Heinrich', 38),
#  ('Mahoney', 38),
#  ('Montecillo', 38),
#  ('Nicolas Feuillatte', 38),
#  ('Ochoa', 38),
#  ('Omaka Springs', 38),
#  ('Pegasus Bay', 38),
#  ('René Muré', 38),
#  ('Sleight of Hand', 38),
#  ('Spann Vineyards', 38),
#  ('Te Awa', 38),
#  ('Trefethen', 38),
#  ('Villa Matilde', 38),
#  ('Whitehall Lane', 38),
#  ('Alois Lageder', 37),
#  ('Argyle', 37),
#  ('Avignonesi', 37),
#  ('Benegas', 37),
#  ('Beni di Batasiolo', 37),
#  ('Binyamina', 37),
#  ('Cesari', 37),
#  ('Chakana', 37),
#  ('De Tierra', 37),
#  ('Frei Brothers', 37),
#  ('Gallo Family Vineyards', 37),
#  ('Goldschmidt', 37),
#  ('Gramercy', 37),
#  ('Heron', 37),
#  ('Hightower', 37),
#  ('Indomita', 37),
#  ('Jean-Baptiste Adam', 37),
#  ('Joh. Jos. Prüm', 37),
#  ('Johannishof', 37),
#  ('Judith Beck', 37),
#  ('Kuleto Estate', 37),
#  ('Matchbook', 37),
#  ('Messias', 37),
#  ('Parras Vinhos', 37),
#  ('Perrier Jouët', 37),
#  ('Plantagenet', 37),
#  ('Poggio Antico', 37),
#  ('Quinta da Alorna', 37),
#  ('Rancho Zabaco', 37),
#  ('Redtree', 37),
#  ('Roux Père et Fils', 37),
#  ('Saintsbury', 37),
#  ('Silvan Ridge', 37),
#  ('Stevenot', 37),
#  ('Veramar', 37),
#  ('Viña Alicia', 37),
#  ('Wattle Creek', 37),
#  ('Adami', 36),
#  ('Alma Rosa', 36),
#  ('Andretti', 36),
#  ('Baron Knyphausen', 36),
#  ('Beau Joubert', 36),
#  ('Bloomer Creek', 36),
#  ('Botalcura', 36),
#  ('Cantina Produttori San Michele Appiano', 36),
#  ('Carabella', 36),
#  ('Cartlidge & Browne', 36),
#  ('Château Tour des Gendres', 36),
#  ('Donatella Cinelli Colombini', 36),
#  ('Ferrari', 36),
#  ('Fielding Hills', 36),
#  ('Four Vines', 36),
#  ('Hard Row To Hoe', 36),
#  ('Jean-Claude Boisset', 36),
#  ('Jim Barry', 36),
#  ('KWV', 36),
#  ('Keating', 36),
#  ('Landmark', 36),
#  ('Langtry', 36),
#  ('Lionel Osmin & Cie', 36),
#  ('Louis Max', 36),
#  ('McIntyre Vineyards', 36),
#  ('Mähler-Besse', 36),
#  ('Paumanok', 36),
#  ('Provenance Vineyards', 36),
#  ('Roche de Bellene', 36),
#  ('Rochioli', 36),
#  ('Signé Vigneron', 36),
#  ('Silver Lake', 36),
#  ('Tagaris', 36),
#  ("Tenuta Sant'Antonio", 36),
#  ('Terra Andina', 36),
#  ('Trentadue', 36),
#  ('Villa Pillo', 36),
#  ('Amavi', 35),
#  ('Bell', 35),
#  ('Bellussi', 35),
#  ('Bodega NQN', 35),
#  ('Capezzana', 35),
#  ('Domaine Laroche', 35),
#  ('Elena Walch', 35),
#  ('Farnese', 35),
#  ('Gilbert Cellars', 35),
#  ('Greenwood Ridge', 35),
#  ('Gustave Lorentz', 35),
#  ('Kestrel', 35),
#  ('Koehler', 35),
#  ('Livio Felluga', 35),
#  ('Madrigal', 35),
#  ('Mount Baker Vineyards', 35),
#  ('Neudorf', 35),
#  ('Nugan Family Estates', 35),
#  ('Robertson Winery', 35),
#  ('Schild Estate', 35),
#  ('Tedeschi', 35),
#  ('Tenuta Argentiera', 35),
#  ('Tilia', 35),
#  ('Toad Hollow', 35),
#  ('Trinitas', 35),
#  ('Twomey', 35),
#  ('Upland Estates', 35),
#  ('Volpaia', 35),
#  ('Yvon Mau', 35),
#  ('Zantho', 35),
#  ('Amity Vineyards', 34),
#  ('B Cellars', 34),
#  ('Baglio di Pianetto', 34),
#  ('Barone Ricasoli', 34),
#  ('Bella', 34),
#  ('Blackbird Vineyards', 34),
#  ('Bodegas Dios Baco S.L.', 34),
#  ('Carmel Road', 34),
#  ('Cecchi', 34),
#  ('Chamisal Vineyards', 34),
#  ('Chatter Creek', 34),
#  ('Clif Family', 34),
#  ('Domaine Christian Moreau Père et Fils', 34),
#  ('Duck Pond', 34),
#  ('Espiritu de Chile', 34),
#  ('Fleming Jenkins', 34),
#  ('Fulkerson', 34),
#  ('Grayson', 34),
#  ('Gård', 34),
#  ('Herdade da Comporta', 34),
#  ('Jarvis', 34),
#  ('Joseph Faiveley', 34),
#  ('Les Vins de Vienne', 34),
#  ('Liberty School', 34),
#  ('Luna Beberide', 34),
#  ('Miraflores', 34),
#  ('Moletto', 34),
#  ('Otis Kenyon', 34),
#  ('Oxford Landing', 34),
#  ('Q', 34),
#  ('Quilceda Creek', 34),
#  ('Seghesio', 34),
#  ('Skouras', 34),
#  ('Summerland', 34),
#  ('Torbreck', 34),
#  ('Tranche', 34),
#  ('Trio Vintners', 34),
#  ('Twisted Oak', 34),
#  ('Venge', 34),
#  ('Vinum Cellars', 34),
#  ('Wirra Wirra', 34),
#  ('Argento', 33),
#  ('Armanino Family Cellars', 33),
#  ('Atwater', 33),
#  ('B.R. Cohn', 33),
#  ('Baglio del Cristo di Campobello', 33),
#  ('Balboa', 33),
#  ('Bodegas Luzón', 33),
#  ('Cass', 33),
#  ('Castillo de Monjardin', 33),
#  ('Château Lagrézette', 33),
#  ('Collier Falls', 33),
#  ('Domaine Rotier', 33),
#  ('Domaines Devillard', 33),
#  ('Dr. H. Thanisch (Erben Thanisch)', 33),
#  ('Dr. Heidemanns-Bergweiler', 33),
#  ('Elyse', 33),
#  ('Envy', 33),
#  ('Falua', 33),
#  ('Foppiano', 33),
#  ('Grattamacco', 33),
#  ('Helix by Reininger', 33),
#  ('Innocent Bystander', 33),
#  ('Joullian', 33),
#  ('Krutz', 33),
#  ('La Tunella', 33),
#  ('Lange', 33),
#  ('Leyda', 33),
#  ('MandraRossa', 33),
#  ('Manzoni', 33),
#  ('Martha Clara', 33),
#  ('Meridian', 33),
#  ('Origin', 33),
#  ('Peter Lehmann', 33),
#  ('Prosper Maufoux', 33),
#  ('Renieri', 33),
#  ('Robert Craig', 33),
#  ('Samsara', 33),
#  ('Spindrift Cellars', 33),
#  ('Stephen Vincent', 33),
#  ('Stoller', 33),
#  ('Stonestreet', 33),
#  ('Tenuta San Guido', 33),
#  ("Tenuta dell'Ornellaia", 33),
#  ('Terrabianca', 33),
#  ('Terre del Marchesato', 33),
#  ('Titus', 33),
#  ('Trust', 33),
#  ('Tulpen', 33),
#  ('Waterstone', 33),
#  ('Zonin', 33),
#  ('Acacia', 32),
#  ('Acorn', 32),
#  ('Anakena', 32),
#  ('Au Bon Climat', 32),
#  ('Barefoot', 32),
#  ('Bodega Renacer', 32),
#  ('Bodegas Franco-Españolas', 32),
#  ('Canoe Ridge', 32),
#  ('Château Bianca', 32),
#  ('Comtesse Thérèse', 32),
#  ('Decoy', 32),
#  ('Emina', 32),
#  ('Finca Torremilanos', 32),
#  ('García Figuero', 32),
#  ('Goats do Roam Wine Co.', 32),
#  ('Hartenberg', 32),
#  ('Henri Bourgeois', 32),
#  ('Hugel', 32),
#  ('Jean-Luc and Paul Aegerter', 32),
#  ('Les Vignerons de la Méditerranée', 32),
#  ('Lis Neris', 32),
#  ('Mailly Grand Cru', 32),
#  ("Marchesi de' Frescobaldi", 32),
#  ('Margerum', 32),
#  ('Newton', 32),
#  ('OS Winery', 32),
#  ('Porta', 32),
#  ('Quinta do Crasto', 32),
#  ('Reininger', 32),
#  ('River Road', 32),
#  ('Shaw', 32),
#  ('Smasne Cellars', 32),
#  ('Speri', 32),
#  ('Tahbilk', 32),
#  ('Taylor Fladgate', 32),
#  ('Tercero', 32),
#  ('Tin Barn', 32),
#  ('Tomero', 32),
#  ('Weinert', 32),
#  ('Xavier Monnot', 32),
#  ('Albert Bichot', 31),
#  ('Boomtown', 31),
#  ('Bortolotti', 31),
#  ('Ciavolich Giuseppe', 31),
#  ('Clayhouse', 31),
#  ("Coeur d'Alene", 31),
#  ('Colomé', 31),
#  ('Colterenzio', 31),
#  ('Coniglio', 31),
#  ('Coto de Hayas', 31),
#  ('Darcie Kent Vineyards', 31),
#  ('Davis Family', 31),
#  ('Domaine Ehrhart', 31),
#  ('Dürnberg', 31),
#  ('Familia Cassone', 31),
#  ('Folin Cellars', 31),
#  ('Gnarly Head', 31),
#  ('Gustafson Family', 31),
#  ('Hess Collection', 31),
#  ('Jardin', 31),
#  ('Kourtaki', 31),
#  ('Le Colture', 31),
#  ('Leth', 31),
#  ('Mezzacorona', 31),
#  ...]
